# %% [markdown]
# #matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10,20,30,40])
plt.show()

# %%
plt.plot([1,2,3,4], [12,43,25,15], color='pinK', label='PINK')
plt.plot([1,2,3,4], [20,44,55,10], 'g.', label='B')
plt.plot([1,2,3,4], [1,5,10,30], label='C', linestyle='--')
plt.rc('font', family = 'Malgun Gothic')
plt.legend(loc = 1)
plt.title('그래프 타이틀')
# Out:
# Text(0.5, 1.0, '그래프 타이틀')

# %%
plt.title('Dow jones Industrial Average')
plt.plot(Open)
plt.figure(figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-914b95561080> in <module>
#       1 plt.title('Dow jones Industrial Average')
# ----> 2 plt.plot(Open)
#       3 plt.figure(figsize=(20,10))
#
# NameError: name 'Open' is not defined
