# %% [markdown]
# # unit8 인구 구조를 다양한 형태로 시각화

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,1))
plt.bar(np.arange(10), np.random.randint(1,10, size=10))
# Out:
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=(5,1))
plt.barh(np.arange(10), np.random.randint(1,10, size=10), label='1')
plt.barh(np.arange(10), -np.random.randint(1,10, size=10), label='2')
plt.legend()

# %% [markdown]
# - 특정 도시의 여성과 남성의 나이별 인구수 대조
# - 컬럼 위치 찾기 : 남 0 ~ 99세, 여 0 ~ 99세
# - 누적값 막대 그래프로 표현

# %%
df = pd.read_csv('gender.csv', encoding = 'cp949')
df = df.replace(',', '', regex=True)
df.shape
'a' in 'abc'
# Out:
# True

# %%
max_age = 99
city = '서울특별시 서초구 방배2동'
man_0 = '2019년05월_남_0세'

# %%
columns = list(df.columns)
man_0_index = list(df.columns).index(man_0)
woman_0_index = list(df.columns).index(woman_0)
columns[man_0_index], columns[man_0_index + max_age]
columns[woman_0_index], columns[woman_0_index + max_age]
# Out:
# ('2019년05월_여_0세', '2019년05월_여_99세')

# %%
woman_0_index
# Out:
# 106

# %%
#df.head()

# %%
data = np.array(df)
area = data[:, 0]
city_row_index = -1
for i in range(len(area)):
    if city in area[i]:
        print(i, area[i])
        city_row_index = i
# Out:
# 13 서울특별시 서초구 방배2동(1165061000)

# %%
city_data = data[city_row_index]
city_data
# Out:
# array(['서울특별시 서초구 방배2동(1165061000)', '10030', '10030', '70', '48', '72',
#        '71', '72', '83', '59', '55', '83', '81', '81', '91', '79', '81',
#        '81', '75', '88', '94', '128', '119', '98', '136', '144', '158',
#        '151', '157', '167', '169', '172', '156', '164', '163', '140',
#        '146', '159', '144', '157', '181', '169', '170', '131', '141',
#        '156', '130', '151', '166', '160', '149', '173', '154', '153',
#        '134', '141', '151', '153', '136', '151', '169', '180', '166',
#        '150', '178', '157', '134', '146', '111', '115', '100', '86',
#        '108', '98', '87', '101', '79', '74', '57', '90', '67', 47, 59, 49,
#        38, 28, 21, 22, 12, 11, 11, 6, 4, 6, 3, 4, 3, 2, 1, 4, 3, 0, 1, 0,
#        '11200', '11200', '56', '66', '71', '68', '62', '55', '59', '68',
#        '75', '62', '68', '78', '81', '64', '95', '89', '88', '98', '86',
#        '110', '112', '117', '141', '154', '158', '166', '178', '194',
#        '219', '198', '198', '193', '172', '172', '169', '181', '162',
#        '189', '168', '186', '153', '117', '163', '174', '166', '202',
#        '194', '168', '177', '192', '182', '197', '171', '181', '195',
#        '173', '175', '170', '200', '204', '204', '196', '186', '163',
#        '190', '137', '120', '115', '106', '111', '110', '130', '109',
#        '83', '79', '67', '83', '66', 50, 47, 52, 46, 27, 24, 35, 14, 26,
#        22, 23, 21, 11, 17, 9, 5, 6, 4, 5, 6, 1, 1, 13], dtype=object)

# %%
city_man = city_data[man_0_index:man_0_index + max_age].astype(np.int)
city_man
# Out:
# array([ 70,  48,  72,  71,  72,  83,  59,  55,  83,  81,  81,  91,  79,
#         81,  81,  75,  88,  94, 128, 119,  98, 136, 144, 158, 151, 157,
#        167, 169, 172, 156, 164, 163, 140, 146, 159, 144, 157, 181, 169,
#        170, 131, 141, 156, 130, 151, 166, 160, 149, 173, 154, 153, 134,
#        141, 151, 153, 136, 151, 169, 180, 166, 150, 178, 157, 134, 146,
#        111, 115, 100,  86, 108,  98,  87, 101,  79,  74,  57,  90,  67,
#         47,  59,  49,  38,  28,  21,  22,  12,  11,  11,   6,   4,   6,
#          3,   4,   3,   2,   1,   4,   3,   0])

# %%
city_woman = city_data[woman_0_index:woman_0_index + max_age].astype(np.int)

# %%
city_man.shape, city_woman.shape
# Out:
# ((99,), (99,))

# %%
m = plt.barh(np.arange(len(city_man)), city_man, label='man')
m = plt.barh(np.arange(len(city_woman)), -city_woman, label='woman')
m = plt.legend

# %% [markdown]
# # 서울의 남녀인구

# %%
# 데이터 읽어오기
df = pd.read_csv('gender.csv', encoding = 'cp949')
df = df.replace(',', '', regex=True)
data = np.array(df)

# 변수설정
max_age = 99
city = '서울'
is_contain = []
area = data[:, 0]

# area에 서울이 포함되어 있으면 is_contain에 포함
for i in range(len(area)):
    is_contain.append(city in area[i])
    
np.mean(is_contain)
city_data = data[is_contain]
city_data.shape
is_contain
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  ...]

# %%
np.sum(city_data, axis=0)
city_man = city_data[:, man_0_index:man_0_index+max_age].astype(np.int)
city_woman = city_data[:, woman_0_index:woman_0_index+max_age].astype(np.int)
city_man = np.sum(city_man, axis=0)
city_woman = np.sum(city_woman, axis=0)
city_man.shape, city_woman.shape
# Out:
# ((99,), (99,))

# %%
plt.title('Seoul')
m = plt.barh(np.arange(len(city_man)), city_man, label = 'man')
m = plt.barh(np.arange(len(city_woman)), -city_woman, label = 'woman')
m = plt.legend()

# %% [markdown]
# # 파이 그래프

# %%
# p130, p140 파이 돌출 효과
plt.rc('font', family='Malgun Gothic')
color = ['darkmagenta', 'deeppink', 'pink']
plt.title("pie graph")
n = plt.pie([10, 20, 30], labels=['A', 'B', 'C'], autopct='%.1f%%', colors=color, explode=(0, 0.2, 0))
n = plt.legend()

# %%
plt.figure(figsize=(5, 1))
p = plt.plot(city_man, label = 'man')
p = plt.plot(city_woman, label = 'woman')
plt.legend()

# %%
plt.title('man/woman population')
plt.pie([np.sum(city_man), np.sum(city_woman)], labels=['M', 'W'], autopct='%d %%', explode=(0, 0.1) )
# Out:
# ([<matplotlib.patches.Wedge at 0x16dbef2c240>,
#   <matplotlib.patches.Wedge at 0x16dbef2ab38>],
#  [Text(0.040116814693150434, 1.099268229859699, 'M'),
#   Text(-0.0437635732923387, -1.1992017134963935, 'W')],
#  [Text(0.021881898923536598, 0.5996008526507448, '48 %'),
#   Text(-0.02552875108719757, -0.6995343328728961, '51 %')])

# %%
# 144 남녀 인구의 차이
plt.bar(np.arange(len(city_man)), city_man-city_woman)
# Out:
# <BarContainer object of 99 artists>

# %%
# 146
color = ['red', 'green', 'black', 'gold']
color = 'blue'
y = np.random.randint(0, 100, size=100)
plt.scatter(np.arange(len(y)), y, s=y, c=range(len(y)), cmap='jet', alpha=0.5)
plt.colorbar()

# %% [markdown]
# # 그래프
# - plot(x), plot(x, y) : 선 그래프
# - hist(x) : 히스토그램
# - boxplot(x) : 박스 그래프
# - bar(x, y), barh(x, y) : 막대 그래프
# - pie(x) : 파이그래프
# - scatter(x, y) : 산점도 그래프
