# %% [markdown]
# ## python_day2

# %% [markdown]
# ![%EC%88%98%EB%8B%AC.jpg](attachment:%EC%88%98%EB%8B%AC.jpg)

# %% [markdown]
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  | table|

# %% [markdown]
# 비디오는 file /download as/ html 로 다운 받아서 열면 동영상이 나옴

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/dZ4vw6v3LcA" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a = []

# %%
a.append(0)

# %%
a
# Out:
# [0]

# %%
a?

# %%
x=987654321
i=1
while(2**i<x):
    i+=1
print('2 ^ {} > {}'.format(i, x))
# Out:
# 2 ^ 30 > 987654321

# %%
b = {'age':25, 'city':'Seoul'}
b['age']
# Out:
# 25

# %%
b['age']+=1

# %%
b
# Out:
# {'age': 26, 'city': 'Seoul'}

# %%
b['part'] = '개발부'

# %%
b
# Out:
# {'age': 26, 'city': 'Seoul', 'part': '개발부'}

# %%
b.keys()
# Out:
# dict_keys(['age', 'city', 'part'])
